# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
tips["tip_percentage"] = (tips["total_bill"] / tips["tip"]) * 100
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2     1682.178218
# 1       10.34  1.66    Male     No  Sun  Dinner     3      622.891566
# 2       21.01  3.50    Male     No  Sun  Dinner     3      600.285714
# 3       23.68  3.31    Male     No  Sun  Dinner     2      715.407855
# 4       24.59  3.61  Female     No  Sun  Dinner     4      681.163435

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
sns.scatterplot(data=tips,x="total_bill",y="tip")
plt.title("SCATTER PLOT")
sns.set_palette("pastel")

# %%
import seaborn as sns
sns.boxplot(data=tips,x="total_bill",y="sex")
plt.title("BOX PLOT")
# Out:
# Text(0.5, 1.0, 'BOX PLOT')

# %%
import seaborn as sns
tips["tip_percentage"] = (tips["total_bill"] / tips["tip"]) * 100
sns.violinplot(data=tips,x="tip_percentage",y="sex")
plt.title("VIOLIN PLOT")
# Out:
# Text(0.5, 1.0, 'VIOLIN PLOT')

# %%
import seaborn as sns
sns.relplot(data=sns.load_dataset("tips"),x="total_bill",y="time")
plt.title("RELPLOT")
# Out:
# Text(0.5, 1.0, 'RELPLOT')
